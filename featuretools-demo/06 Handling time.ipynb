# %% [markdown]
# # Handling time
#
# https://featuretools.alteryx.com/en/stable/getting_started/handling_time.html
#
# Use the time index and provide a cutoff time during feature calculation to automatically filter out data after the cutoff time. Useful for e.g. training/test set splits.

# %% [markdown]
# ## Time index
#
# Used to specify a data column to be used as a timestamp.

# %%
import featuretools as ft
import pandas as pd

# %%
es = ft.demo.load_mock_customer(return_entityset = True, random_seed = 0)
es["transactions"].head()
# Out:
#      transaction_id  session_id    transaction_time product_id  amount  \
# 298             298           1 2014-01-01 00:00:00          5  127.64
# 2                 2           1 2014-01-01 00:01:05          2  109.48
# 308             308           1 2014-01-01 00:02:10          3   95.06
# 116             116           1 2014-01-01 00:03:15          4   78.92
# 371             371           1 2014-01-01 00:04:20          3   31.54
#
#           _ft_last_time
# 298 2014-01-01 00:00:00
# 2   2014-01-01 00:01:05
# 308 2014-01-01 00:02:10
# 116 2014-01-01 00:03:15
# 371 2014-01-01 00:04:20

# %% [markdown]
# In this example, `transaction-time` is the time index. The `_ft_last_time` column was generated by Featuretools.

# %%
es["customers"]
# Out:
#    customer_id zip_code           join_date   birthday       _ft_last_time
# 5            5    60091 2010-07-17 05:27:50 1984-07-28 2014-01-01 08:09:40
# 4            4    60091 2011-04-08 20:08:14 2006-08-15 2014-01-01 05:31:30
# 1            1    60091 2011-04-17 10:48:33 1994-07-18 2014-01-01 07:26:20
# 3            3    13244 2011-08-13 15:42:34 2003-11-21 2014-01-01 09:00:35
# 2            2    13244 2012-04-15 23:31:04 1986-08-18 2014-01-01 08:23:45

# %% [markdown]
# Here note that only `join_date` should be used as the time index; DOB should not be used for that purpose.

# %% [markdown]
# ## Cutoff time
#
# Specifies the last point in time that data can be used to calculate features. For example, to set a cutoff time of 4 AM on Jan 1, 2014:

# %%
fm, features = ft.dfs(
    entityset = es,
    target_dataframe_name="customers",
    cutoff_time = pd.Timestamp("2014-1-1 04:00"),
    instance_ids = [1, 2, 3],
    cutoff_time_in_index = True,
)
fm
# Out:
#                                 zip_code  COUNT(sessions)  \
# customer_id time
# 1           2014-01-01 04:00:00    60091                4
# 2           2014-01-01 04:00:00    13244                4
# 3           2014-01-01 04:00:00    13244                1
#
#                                 MODE(sessions.device)  \
# customer_id time
# 1           2014-01-01 04:00:00                tablet
# 2           2014-01-01 04:00:00               desktop
# 3           2014-01-01 04:00:00                tablet
#
#                                  NUM_UNIQUE(sessions.device)  \
# customer_id time
# 1           2014-01-01 04:00:00                            3
# 2           2014-01-01 04:00:00                            2
# 3           2014-01-01 04:00:00                            1
#
#                                  COUNT(transactions)  \
# customer_id time
# 1           2014-01-01 04:00:00                   67
# 2           2014-01-01 04:00:00                   49
# 3           2014-01-01 04:00:00                   15
#
#                                  MAX(transactions.amount)  \
# customer_id time
# 1           2014-01-01 04:00:00                    139.23
# 2           2014-01-01 04:00:00                    146.81
# 3           2014-01-01 04:00:00                    146.31
#
#                                  MEAN(transactions.amount)  \
# customer_id time
# 1           2014-01-01 04:00:00                  74.002836
# 2           2014-01-01 04:00:00                  84.700000
# 3           2014-01-01 04:00:00                  62.791333
#
#                                  MIN(transactions.amount)  \
# customer_id time
# 1           2014-01-01 04:00:00                      5.81
# 2           2014-01-01 04:00:00                     12.07
# 3           2014-01-01 04:00:00                      8.19
#
#                                 MODE(transactions.product_id)  \
# customer_id time
# 1           2014-01-01 04:00:00                             4
# 2           2014-01-01 04:00:00                             4
# 3           2014-01-01 04:00:00                             1
#
#                                  NUM_UNIQUE(transactions.product_id)  ...  \
# customer_id time                                                      ...
# 1           2014-01-01 04:00:00                                    5  ...
# 2           2014-01-01 04:00:00                                    5  ...
# 3           2014-01-01 04:00:00                                    5  ...
#
#                                  STD(sessions.SKEW(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                                 0.500353
# 2           2014-01-01 04:00:00                                 0.324809
# 3           2014-01-01 04:00:00                                      NaN
#
#                                  STD(sessions.SUM(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                              271.917637
# 2           2014-01-01 04:00:00                              307.743859
# 3           2014-01-01 04:00:00                                     NaN
#
#                                  SUM(sessions.MAX(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                                  540.04
# 2           2014-01-01 04:00:00                                  569.29
# 3           2014-01-01 04:00:00                                  146.31
#
#                                 SUM(sessions.MEAN(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                              304.601700
# 2           2014-01-01 04:00:00                              340.791792
# 3           2014-01-01 04:00:00                               62.791333
#
#                                 SUM(sessions.MIN(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                                  27.62
# 2           2014-01-01 04:00:00                                 105.24
# 3           2014-01-01 04:00:00                                   8.19
#
#                                 SUM(sessions.NUM_UNIQUE(transactions.product_id))  \
# customer_id time
# 1           2014-01-01 04:00:00                                              20.0
# 2           2014-01-01 04:00:00                                              20.0
# 3           2014-01-01 04:00:00                                               5.0
#
#                                 SUM(sessions.SKEW(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                               -0.505043
# 2           2014-01-01 04:00:00                                0.045171
# 3           2014-01-01 04:00:00                                0.618455
#
#                                 SUM(sessions.STD(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                             169.572874
# 2           2014-01-01 04:00:00                             157.262738
# 3           2014-01-01 04:00:00                              47.264797
#
#                                 MODE(transactions.sessions.device)  \
# customer_id time
# 1           2014-01-01 04:00:00                             tablet
# 2           2014-01-01 04:00:00                            desktop
# 3           2014-01-01 04:00:00                             tablet
#
#                                 NUM_UNIQUE(transactions.sessions.device)
# customer_id time
# 1           2014-01-01 04:00:00                                        3
# 2           2014-01-01 04:00:00                                        2
# 3           2014-01-01 04:00:00                                        1
#
# [3 rows x 75 columns]

# %% [markdown]
# We can provide cutoff times in a dataframe.

# %%
cutoff_times = pd.DataFrame()
cutoff_times["customer_id"] = [1, 2, 3, 1]
cutoff_times["time"] = pd.to_datetime(
    ["2014-1-1 04:00", "2014-1-1 05:00", "2014-1-1 06:00", "2014-1-1 08:00"]
)
cutoff_times["label"] = [True, True, False, True]
cutoff_times
fm, features = ft.dfs(
    entityset=es,
    target_dataframe_name="customers",
    cutoff_time=cutoff_times,
    cutoff_time_in_index=True,
)
fm
# Out:
#                                 zip_code  COUNT(sessions)  \
# customer_id time
# 1           2014-01-01 04:00:00    60091                4
# 2           2014-01-01 05:00:00    13244                5
# 3           2014-01-01 06:00:00    13244                4
# 1           2014-01-01 08:00:00    60091                8
#
#                                 MODE(sessions.device)  \
# customer_id time
# 1           2014-01-01 04:00:00                tablet
# 2           2014-01-01 05:00:00               desktop
# 3           2014-01-01 06:00:00               desktop
# 1           2014-01-01 08:00:00                mobile
#
#                                  NUM_UNIQUE(sessions.device)  \
# customer_id time
# 1           2014-01-01 04:00:00                            3
# 2           2014-01-01 05:00:00                            2
# 3           2014-01-01 06:00:00                            2
# 1           2014-01-01 08:00:00                            3
#
#                                  COUNT(transactions)  \
# customer_id time
# 1           2014-01-01 04:00:00                   67
# 2           2014-01-01 05:00:00                   62
# 3           2014-01-01 06:00:00                   44
# 1           2014-01-01 08:00:00                  126
#
#                                  MAX(transactions.amount)  \
# customer_id time
# 1           2014-01-01 04:00:00                    139.23
# 2           2014-01-01 05:00:00                    146.81
# 3           2014-01-01 06:00:00                    146.31
# 1           2014-01-01 08:00:00                    139.43
#
#                                  MEAN(transactions.amount)  \
# customer_id time
# 1           2014-01-01 04:00:00                  74.002836
# 2           2014-01-01 05:00:00                  83.149355
# 3           2014-01-01 06:00:00                  65.174773
# 1           2014-01-01 08:00:00                  71.631905
#
#                                  MIN(transactions.amount)  \
# customer_id time
# 1           2014-01-01 04:00:00                      5.81
# 2           2014-01-01 05:00:00                     12.07
# 3           2014-01-01 06:00:00                      6.65
# 1           2014-01-01 08:00:00                      5.81
#
#                                 MODE(transactions.product_id)  \
# customer_id time
# 1           2014-01-01 04:00:00                             4
# 2           2014-01-01 05:00:00                             4
# 3           2014-01-01 06:00:00                             1
# 1           2014-01-01 08:00:00                             4
#
#                                  NUM_UNIQUE(transactions.product_id)  ...  \
# customer_id time                                                      ...
# 1           2014-01-01 04:00:00                                    5  ...
# 2           2014-01-01 05:00:00                                    5  ...
# 3           2014-01-01 06:00:00                                    5  ...
# 1           2014-01-01 08:00:00                                    5  ...
#
#                                  STD(sessions.SUM(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                              271.917637
# 2           2014-01-01 05:00:00                              266.912832
# 3           2014-01-01 06:00:00                              417.557763
# 1           2014-01-01 08:00:00                              279.510713
#
#                                  SUM(sessions.MAX(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                                  540.04
# 2           2014-01-01 05:00:00                                  688.14
# 3           2014-01-01 06:00:00                                  493.07
# 1           2014-01-01 08:00:00                                 1057.97
#
#                                  SUM(sessions.MEAN(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                               304.601700
# 2           2014-01-01 05:00:00                               418.096407
# 3           2014-01-01 06:00:00                               290.968018
# 1           2014-01-01 08:00:00                               582.193117
#
#                                 SUM(sessions.MIN(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                                  27.62
# 2           2014-01-01 05:00:00                                 127.06
# 3           2014-01-01 06:00:00                                 126.66
# 1           2014-01-01 08:00:00                                  78.59
#
#                                 SUM(sessions.NUM_UNIQUE(transactions.product_id))  \
# customer_id time
# 1           2014-01-01 04:00:00                                              20.0
# 2           2014-01-01 05:00:00                                              25.0
# 3           2014-01-01 06:00:00                                              16.0
# 1           2014-01-01 08:00:00                                              40.0
#
#                                 SUM(sessions.SKEW(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                               -0.505043
# 2           2014-01-01 05:00:00                               -0.269747
# 3           2014-01-01 06:00:00                                0.860577
# 1           2014-01-01 08:00:00                               -0.476122
#
#                                 SUM(sessions.STD(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                             169.572874
# 2           2014-01-01 05:00:00                             190.987775
# 3           2014-01-01 06:00:00                             119.136697
# 1           2014-01-01 08:00:00                             312.745952
#
#                                 MODE(transactions.sessions.device)  \
# customer_id time
# 1           2014-01-01 04:00:00                             tablet
# 2           2014-01-01 05:00:00                            desktop
# 3           2014-01-01 06:00:00                            desktop
# 1           2014-01-01 08:00:00                             mobile
#
#                                 NUM_UNIQUE(transactions.sessions.device)  \
# customer_id time
# 1           2014-01-01 04:00:00                                        3
# 2           2014-01-01 05:00:00                                        2
# 3           2014-01-01 06:00:00                                        2
# 1           2014-01-01 08:00:00                                        3
#
#                                  label
# customer_id time
# 1           2014-01-01 04:00:00   True
# 2           2014-01-01 05:00:00   True
# 3           2014-01-01 06:00:00  False
# 1           2014-01-01 08:00:00   True
#
# [4 rows x 76 columns]

# %% [markdown]
# Now it's straightforward to set a training window when performing DFS.

# %%
window_fm, window_features = ft.dfs(
    entityset=es,
    target_dataframe_name="customers",
    cutoff_time=cutoff_times,
    cutoff_time_in_index=True,
    training_window="2 hour",
)

window_fm
# Out:
#                                 zip_code  COUNT(sessions)  \
# customer_id time
# 1           2014-01-01 04:00:00    60091                2
# 2           2014-01-01 05:00:00    13244                3
# 3           2014-01-01 06:00:00    13244                3
# 1           2014-01-01 08:00:00    60091                3
#
#                                 MODE(sessions.device)  \
# customer_id time
# 1           2014-01-01 04:00:00               desktop
# 2           2014-01-01 05:00:00               desktop
# 3           2014-01-01 06:00:00               desktop
# 1           2014-01-01 08:00:00                mobile
#
#                                  NUM_UNIQUE(sessions.device)  \
# customer_id time
# 1           2014-01-01 04:00:00                            2
# 2           2014-01-01 05:00:00                            2
# 3           2014-01-01 06:00:00                            1
# 1           2014-01-01 08:00:00                            2
#
#                                  COUNT(transactions)  \
# customer_id time
# 1           2014-01-01 04:00:00                   27
# 2           2014-01-01 05:00:00                   31
# 3           2014-01-01 06:00:00                   29
# 1           2014-01-01 08:00:00                   47
#
#                                  MAX(transactions.amount)  \
# customer_id time
# 1           2014-01-01 04:00:00                    139.09
# 2           2014-01-01 05:00:00                    146.81
# 3           2014-01-01 06:00:00                    128.26
# 1           2014-01-01 08:00:00                    139.43
#
#                                  MEAN(transactions.amount)  \
# customer_id time
# 1           2014-01-01 04:00:00                  76.950370
# 2           2014-01-01 05:00:00                  84.051935
# 3           2014-01-01 06:00:00                  66.407586
# 1           2014-01-01 08:00:00                  66.471277
#
#                                  MIN(transactions.amount)  \
# customer_id time
# 1           2014-01-01 04:00:00                      5.81
# 2           2014-01-01 05:00:00                     12.07
# 3           2014-01-01 06:00:00                      6.65
# 1           2014-01-01 08:00:00                      5.91
#
#                                 MODE(transactions.product_id)  \
# customer_id time
# 1           2014-01-01 04:00:00                             4
# 2           2014-01-01 05:00:00                             4
# 3           2014-01-01 06:00:00                             1
# 1           2014-01-01 08:00:00                             4
#
#                                  NUM_UNIQUE(transactions.product_id)  ...  \
# customer_id time                                                      ...
# 1           2014-01-01 04:00:00                                    5  ...
# 2           2014-01-01 05:00:00                                    5  ...
# 3           2014-01-01 06:00:00                                    5  ...
# 1           2014-01-01 08:00:00                                    5  ...
#
#                                  STD(sessions.SUM(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                               18.667619
# 2           2014-01-01 05:00:00                              203.331699
# 3           2014-01-01 06:00:00                              477.281339
# 1           2014-01-01 08:00:00                              330.655558
#
#                                  SUM(sessions.MAX(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                                  271.81
# 2           2014-01-01 05:00:00                                  404.04
# 3           2014-01-01 06:00:00                                  346.76
# 1           2014-01-01 08:00:00                                  384.44
#
#                                  SUM(sessions.MEAN(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                               155.604500
# 2           2014-01-01 05:00:00                               253.240615
# 3           2014-01-01 06:00:00                               228.176684
# 1           2014-01-01 08:00:00                               198.984750
#
#                                 SUM(sessions.MIN(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                                  12.59
# 2           2014-01-01 05:00:00                                  90.35
# 3           2014-01-01 06:00:00                                 118.47
# 1           2014-01-01 08:00:00                                  24.61
#
#                                 SUM(sessions.NUM_UNIQUE(transactions.product_id))  \
# customer_id time
# 1           2014-01-01 04:00:00                                              10.0
# 2           2014-01-01 05:00:00                                              15.0
# 3           2014-01-01 06:00:00                                              11.0
# 1           2014-01-01 08:00:00                                              15.0
#
#                                 SUM(sessions.SKEW(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                               -0.604638
# 2           2014-01-01 05:00:00                               -0.110009
# 3           2014-01-01 06:00:00                                0.242122
# 1           2014-01-01 08:00:00                               -0.003438
#
#                                 SUM(sessions.STD(transactions.amount))  \
# customer_id time
# 1           2014-01-01 04:00:00                              86.730914
# 2           2014-01-01 05:00:00                             109.500185
# 3           2014-01-01 06:00:00                              71.871900
# 1           2014-01-01 08:00:00                             107.128899
#
#                                 MODE(transactions.sessions.device)  \
# customer_id time
# 1           2014-01-01 04:00:00                            desktop
# 2           2014-01-01 05:00:00                            desktop
# 3           2014-01-01 06:00:00                            desktop
# 1           2014-01-01 08:00:00                             mobile
#
#                                 NUM_UNIQUE(transactions.sessions.device)  \
# customer_id time
# 1           2014-01-01 04:00:00                                        2
# 2           2014-01-01 05:00:00                                        2
# 3           2014-01-01 06:00:00                                        1
# 1           2014-01-01 08:00:00                                        2
#
#                                  label
# customer_id time
# 1           2014-01-01 04:00:00   True
# 2           2014-01-01 05:00:00   True
# 3           2014-01-01 06:00:00  False
# 1           2014-01-01 08:00:00   True
#
# [4 rows x 76 columns]

# %% [markdown]
# Various options are included to tweak the behavior, e.g. `include_cutoff_time = False` would be an open interval, and not include entries equal to that cutoff time.

# %% [markdown]
# ## Rounding cutoff times
#
# Cutoff times can be rounded off to a chosen time unit. This speeds up DFS at the cost of losing a (small) bit of information.
